# %%
import pandas as pd
from os import path

# Edit path if need be (shouldn't need to b/c we all have the same folder structure)
CSV_PATH_1 = '../Videos/all_data'
CSV_PATH_2 = '../Videos2/all_data2'
FILE_EXTENSION = '_all.csv'
GENRES = ['country', 'edm', 'pop', 'rap', 'rock']

# Containers for the data frames
genre_dfs = {}
all_genres = None


# Read in the 5 genre's of CV's
for genre in GENRES:
    genre_csv_path_1 = path.join(CSV_PATH_1, genre) + FILE_EXTENSION
    genre_csv_path_2 = path.join(CSV_PATH_2, genre) + FILE_EXTENSION
    df_1 = pd.read_csv(genre_csv_path_1)
    df_2 = pd.read_csv(genre_csv_path_2)
    print df_1.columns
    df_1 = df_1.drop('Unnamed: 0',1)
    df_2 = df_2.drop('Unnamed: 0',1)
    print df_1
    df_combined = pd.concat([df_1,df_2],ignore_index=True)
    genre_dfs[genre] = df_combined

all_genres = pd.concat(genre_dfs.values())
print len(all_genres)
all_genres.head()

# genre_dfs is now a dictionary that contains the 5 different data frames
# all_genres is a dataframe that contains all of the data
# Out:
# Index([u'Unnamed: 0', u'filename', u'author', u'description', u'viewcount',
#        u'rating', u'likes', u'dislikes', u'duration', u'length', u'keywords',
#        u'published', u'colors_1_red', u'colors_1_blue', u'colors_1_green',
#        u'colors_2_red', u'colors_2_blue', u'colors_2_green', u'colors_3_red',
#        u'colors_3_blue', u'colors_3_green', u'colors_4_red', u'colors_4_blue',
#        u'colors_4_green', u'colors_5_red', u'colors_5_blue', u'colors_5_green',
#        u'colors_6_red', u'colors_6_blue', u'colors_6_green', u'colors_7_red',
#        u'colors_7_blue', u'colors_7_green', u'colors_8_red', u'colors_8_blue',
#        u'colors_8_green', u'colors_9_red', u'colors_9_blue', u'colors_9_green',
#        u'colors_10_red', u'colors_10_blue', u'colors_10_green', u'genre'],
#       dtype='object')
#                                              filename  \
# 0                     Luke Bryan - Roller Coaster.mp4
# 1               Dierks Bentley - Drunk On A Plane.mp4
# 2              Thomas Rhett - Get Me Some Of That.mp4
# 3                 David Nail - Whatever She's Got.mp4
# 4                              Joe Nichols - Yeah.mp4
# 5                Jack Ingram - Barefoot And Crazy.3gp
# 6                      Eric Paslay - Friday Night.mp4
# 7                          Kip Moore - Beer Money.mp4
# 8    Cole Swindell - Chillin' It (Official Video).mp4
# 9          Randy Houser - Runnin' Outta Moonlight.mp4
# 10    Blake Shelton - Neon Light (Official Audio).mp4
# 11   Jason Aldean - Burnin' It Down (Lyric Video).mp4
# 12             Kenny Chesney - Flora-Bama (Audio).mp4
# 13             Tim McGraw - Lookin' For That Girl.mp4
# 14                    Chase Rice - Ready Set Roll.mp4
# 15                            Jason Aldean - 1994.mp4
# 16                  Brantley Gilbert - Bottoms Up.mp4
# 17  Florida Georgia Line - This Is How We Roll ft....
# 18                  Jason Aldean - My Kinda Party.3gp
# 19  Brantley Gilbert - Small Town Throwdown ft. Ju...
# 20                         Eric Church - Creepin'.mp4
# 21                    Luke Bryan - Crash My Party.mp4
# 22         Kenny Chesney - When The Sun Goes Down.3gp
# 23                           Jake Owen - Beachin'.mp4
# 24                  Kenny Chesney - American Kids.mp4
# 60  [Who I Am with You, official, hq, Chris Young ...   ...              40
# 61  [James Otto, Just Got Started Lovin' You, Coun...   ...              30
# 62  [George Strait (Musical Artist), Brad Paisley ...   ...              70
# 63  [Jason Michael Carroll, Arista Nashville, Coun...   ...              70
# 64  [crushin it, she's everything, official, hq, b...   ...              20
# 65  [Eric, Church, Springsteen, EMI, Records, Nash...   ...              60
# 66  [back, road, official, atkins, rodney, country...   ...              40
# 67  [play something country, guitar lesson, brooks...   ...              50
# 68  [Willie, Nelson, Lost, Highway, Records, Country]   ...              50
# 69  [Billy, Currington, Hey, Girl, Mercury, Nashvi...   ...              70
# 70  [Jake, Owen, Tell, Me, RCA, Records, Label, Na...   ...             200
# 71  [Luke, Bryan, That's, My, Kind, Of, Night, Cap...   ...              10
# 72  [Easton, Corbin, All, Over, The, Road, Mercury...   ...             100
# 73  [the road and the radio, gh 2, official, hq, w...   ...              50
# 74  [PARMALEE, Carolina, Stoney, Creek, Records, C...   ...               0
# 75  [Alan Jackson live, alan jackson drive for dad...   ...             220
# 76  [the road and the radio, gh 2, walmart, offici...   ...             250
# 77          [George, Strait, MCA, Nashville, Country]   ...              60
# 78  [Jason, Aldean, Night, Train, Broken, Bow, Rec...   ...              20
# 79  [the road and the radio, gh 2, anything but mi...   ...              90
# 80  [the road and the radio, gh 2, you and tequila...   ...              80
# 81  [Florida Georgia, Line Stay, Nashville, Countr...   ...              50
# 82  [Broken Bow Records, Jason Aldean, My Kinda Pa...   ...              10
# 83  [Josh, Thompson, Cold, Beer, With, Your, Name,...   ...              20
# 84  [Whiskey in My Water (Official Lyric Video), T...   ...              60
# 85  [Blake, Shelton, Good Ole Boys, Lyrics, blake ...   ...             260
# 86  [Jason, Aldean, Take, Little, Ride, Broken, Bo...   ...              40
#
#     colors_8_blue  colors_8_green  colors_9_red  colors_9_blue  \
# 0             210             190            90             70
# 1              50              50           100            110
# 2              50              30            50             70
# 3              50              30            60             40
# 4              50              50            20             40
# 5              50              30            30             20
# 6              40              30            30             10
# 7              50              40             0             10
# 8              50              60           250            230
# 9              10              40            30             30
# 10             30              30            40             20
# 11             10               0            50             20
# 12            220             150            50             30
# 13             30              20            30             20
# 14             10              40            10             20
# 15             90              70            90             90
# 16             10              20            70             50
# 17             30              30            10             20
# 18            260             240            30             30
# 19             10              20            30             10
# 20             30              40            30             50
# 21            180             170            70             50
# 22             20               0           260            220
# 23            260             230           100            150
# 24            230             200           250            230
# 25             50              50            80             60
# 26             40              70            40             30
# 27             50              40            50             20
# 28             30              50            20             20
# 29             30               0            10             30
# ..            ...             ...           ...            ...
# 57            100             110            80             90
# 58             20               0           260            260
# 59             30               0            30              0
# 60             40              20            60             50
# 61             50              50            10             30
# 62             60              40            30             30
# 63             50              50            30             20
# 64              0               0            50             20
# 65             20              10            50             20
# 66             40              60            90             80
# 67             30               0            40             20
# 68             20              20            40             10
# 69             60              50           180            170
# 70            190             170            90             60
# 71             20               0           240            240
# 72             80              70            80             60
# 73             60              80            70             80
# 74              0              70             0              0
# 75            230             210            20             10
# 76            250             230           150            140
# 77             80              90            20             40
# 78             10               0           240            220
# 79            100              80           110            110
# 80             60              50           120            100
# 81             60              90            50             60
# 82             30              30            10             30
# 83             20               0            40             20
# 84             50              30            80             70
# 85            250             230           210            230
# 86             30              10            30             10
#
#     colors_9_green  colors_10_red  colors_10_blue  colors_10_green    genre
# 0               70            240             220              200  country
# 1              120             90              70               70  country
# 2               50             40              60               50  country
# 3               30             70              60               50  country
# 4               60             20              30               50  country
# 5               10             20              40               40  country
# 6               10             50              30               30  country
# 7               20             50              30               20  country
# 8              220            250             240              220  country
# 9               50             20              20               40  country
# 10              20             90              50               40  country
# 11              20             40              20               10  country
# 12              30            220             210              150  country
# 13              10             30               0               10  country
# 14              50             10              10               50  country
# 15              70            110             110               90  country
# 16              40             10              20               40  country
# 17               0              0              20               30  country
# 18              10             20              30               10  country
# 19              20             60              40               40  country
# 20              50             20              50               60  country
# 21              40            170             160              150  country
# 22             170            260             230              180  country
# 23             150            150             190              180  country
# 24             190             50              30               20  country
# 25              50             60              50               40  country
# 26              20             30              50               90  country
# 27              10             70              50               40  country
# 28              40             10              10               40  country
# 29              20             10              20                0  country
# ..             ...            ...             ...              ...      ...
# 57             100             70              80               90  country
# 58             240             50              40               30  country
# 59               0             50              10                0  country
# 60              30             70              50               20  country
# 61              40             40              20               10  country
# 62              10             60              50               40  country
# 63              10             30              10               20  country
# 64              10             30              10                0  country
# 65              20             60              30               20  country
# 66              70             90              70               60  country
# 67               0            200             250              260  country
# 68              10             50              20               10  country
# 69             160             30              10                0  country
# 70              30            170             150              130  country
# 71             220            250             240              220  country
# 72              50            110              90               80  country
# 73             100             20              20               40  country
# 74             100              0               0               90  country
# 75               0            230             230              210  country
# 76             130            250             240              220  country
# 77              50             50              70               80  country
# 78             200            240             230              200  country
# 79              90             70              60               50  country
# 80              80             90              80               60  country
# 81             100             60              70              100  country
# 82              40             40              50               60  country
# 83              10             50              40               30  country
# 84              40             80              70               50  country
# 85             230              0              20               30  country
# 86               0             30              30               10  country
#
# [87 rows x 42 columns]
# Index([u'Unnamed: 0', u'filename', u'author', u'description', u'viewcount',
#        u'rating', u'likes', u'dislikes', u'duration', u'length', u'keywords',
#        u'published', u'colors_1_red', u'colors_1_blue', u'colors_1_green',
#        u'colors_2_red', u'colors_2_blue', u'colors_2_green', u'colors_3_red',
#        u'colors_3_blue', u'colors_3_green', u'colors_4_red', u'colors_4_blue',
#        u'colors_4_green', u'colors_5_red', u'colors_5_blue', u'colors_5_green',
#        u'colors_6_red', u'colors_6_blue', u'colors_6_green', u'colors_7_red',
#        u'colors_7_blue', u'colors_7_green', u'colors_8_red', u'colors_8_blue',
#        u'colors_8_green', u'colors_9_red', u'colors_9_blue', u'colors_9_green',
#        u'colors_10_red', u'colors_10_blue', u'colors_10_green', u'genre'],
#       dtype='object')
#                                              filename               author  \
# 0   Adam Rickfors feat Marylin - Colors (Official ...         Uniform Beat
# 1   Dillon Francis - Without You ft. T.E.E.D. [Off...       Dillon Francis
# 2   CLMD vs. Kish feat. Fröder - The Stockholm Syn...             CLMDVEVO
# 3   Gareth Emery feat. Christina Novelli - Concret...         Gareth Emery
# 21     1110         8  00:03:35     215
# 22     1243        26  00:03:52     232
# 23    53407      1245  00:03:55     235
# 24   157754      5790  00:03:51     231
# 25   126292      4477  00:03:43     223
# 26   127487      2030  00:03:02     182
# 27   707327     11653  00:04:03     243
# 28    48951       761  00:03:42     222
# 29   296411     12752  00:04:44     284
# ..      ...       ...       ...     ...
# 52     2132        29  00:06:14     374
# 53    50469       904  00:03:37     217
# 54    70412      3770  00:05:37     337
# 55     2687        41  00:03:58     238
# 56   899259     26552  00:04:23     263
# 57     4783       164  00:05:37     337
# 58   128574      3680  00:03:06     186
# 59    58324      1387  00:02:49     169
# 60     4222       216  00:03:28     208
# 61    64152      2155  00:03:30     210
# 62    10550       483  00:02:54     174
# 63     6341       299  00:03:09     189
# 64   117220      2565  00:03:43     223
# 65     5591       334  00:03:49     229
# 66    18288       264  00:04:00     240
# 67     5977       282  00:03:22     202
# 68   102461      1981  00:03:19     199
# 69   600435     12164  00:04:14     254
# 70   187775      3485  00:04:06     246
# 71    72426      3415  00:03:27     207
# 72    68514      1012  00:04:02     242
# 73    37189      2143  00:04:08     248
# 74    32125      1343  00:02:57     177
# 75    14412       660  00:03:48     228
# 76    20400       427  00:03:32     212
# 77    16390       376  00:03:29     209
# 78    15631       277  00:03:57     237
# 79    39065       711  00:03:25     205
# 80     5393       149  00:03:20     200
# 81     9682       232  00:03:14     194
#
#                                              keywords  ...   colors_8_red  \
# 0                                                      ...             30
# 1   [Dillon Francis (Person), dillonfrancis, Total...  ...             80
# 2   [CLMD, The, Stockholm, Syndrome, AbsoluteMarke...  ...             50
# 3   [gareth, emery, trance, house, techno, edm, ed...  ...             80
# 4   [Zedd, new song, new video, Hayley Williams, P...  ...             60
# 5   [Avicii, You, Make, Me, (Official), Universal,...  ...            130
# 6   [Avicii, Levels, Universal, Music, Dance, EDM,...  ...            160
# 7                            [Егор, Клюев, Интернет3]  ...             10
# 8   [animals, official video, Electro House (Music...  ...            190
# 9   [Calvin Harris lyrics, Summer, official, Calvi...  ...            130
# 10  [destructo, higher, agata alexander, gary rich...  ...             40
# 11  [destructo, hard, technology, dance, l.a., boy...  ...             60
# 12  [ultra records, ultra music, ultrarecords, ult...  ...            160
# 13                  [Die Antwoord, Roger Ballen, Zef]  ...             30
# 14                   [212, Azealia Banks, L8R, HOUSE]  ...             20
# 15  [Iggy, Azalea, Work, Mercury, Records, Limited...  ...             30
# 16      [Collard Greens, Schoolboy Q, Kendrick Lamar]  ...             30
# 17  [above & beyond, above and beyond, group thera...  ...             70
# 18  [dpat, bloom, in bloom, vash, jeff vash, soule...  ...             60
# 19  [sami, dub, electronic, slow, revenge, girl, b...  ...             50
# 20  [sleepyhead, rainbow, thorns, trip, hop, dub, ...  ...             60
# 21                                                     ...            100
# 22                                [LA, FUNKY, 103112]  ...             50
# 23  [cazzette, beam me up, spotify, final cut, at ...  ...             20
# 24  [Calvin Harris lyrics, Summer, official, Calvi...  ...             50
# 25  [dance, EDM, Tim Berg, musikvideo, KontorTV, e...  ...             70
# 26  [justice, dance, d a n c e, d.a.n.c.e., music ...  ...             60
# 27  [Fleur, Manu, Division, M83, Midnight City, Mu...  ...             60
# 28  [martin solveig, the night out, Smash, A-Trak,...  ...             50
# 29     [Avicii, Silhouettes, Universal, Music, Dance]  ...            190
# ..                                                ...  ...            ...
# 52  [Nero, Choices, Welcome Reality, 2011, 2012, n...  ...            200
# 53  [Purity, Ring, Fineshrine, Shrines, Brewer, 4A...  ...             50
# 54  [knife, party, internet, friends, music, video...  ...             30
# 55  [Zach Farro, Zac Farro, Ambient, Electronic, M...  ...             50
# 56    [Avicii, Hey, Brother, Universal, Music, Dance]  ...             30
# 57  [ultra records, ultra music, ultrarecords, ult...  ...             70
# 58  [dvbbs, Stampede, borgeous, dimitri vegas, lik...  ...              0
# 59  [Yellow Claw, rochelle, shotgun, Spinnin' Reco...  ...            200
# 60  [Klingande, Jubel, Official Music Video, deep ...  ...             50
# 61  [New World Sound, Thomas Newson, Flute, Music ...  ...             70
# 62  [A-Minor, Thinking Bout The Things, music vide...  ...             50
# 63  [Storm Queen, Look Right Through, Official Mus...  ...             50
# 64  [Don Diablo (Musical Artist), Origins, Arkham ...  ...             30
# 65  [Leon Bolier (Musical Artist), Spell, Spinnin'...  ...             30
# 66  [Don Diablo (Musical Artist), Edge Of The Eart...  ...            120
# 67  [Ray Foxx, Rachel K Collier, Boom Boom, Heartb...  ...             40
# 68  [parra for cuva, anna naklab, wicked games, of...  ...             70
# 69  [Booyah, Showtek (Musical Group), we are loud,...  ...             50
# 70  [Nervo (Musical Group), R3hab (Musical Artist)...  ...            150
# 71  [Spinnin', Records, presents, Samsobeats, Snea...  ...             60
# 72  [NERVO & Hook N Sling, Reason Original Mix, Mu...  ...              0
# 73  [Cedric Gervais, Molly, Cedric, Gervais, madon...  ...            110
# 74  [Bingo Players, Far East Movement, Get Up (Rat...  ...            230
# 75  [Martin, Solveig, Dragonette, ft., Idoling, Bi...  ...            240
# 76  [Starkillers, Dmitry KO, Amba Shepherd, Let Th...  ...            190
# 77  [Sander, van, Doorn, chasin, chasing, spinninT...  ...            220
# 78  [daddys groove, stellar, Spinnin TV, Spinnin, ...  ...              0
# 79  [Showtek (Musical Group), Tiësto (Musical Arti...  ...             30
# 80  [Chrizzo, Maxim, Amanda, Wilson, Seek, Bromanc...  ...             70
# 81  [''official'', ''videoclip'', ''music, video''...  ...            190
#
#     colors_8_blue  colors_8_green  colors_9_red  colors_9_blue  \
# 0              10              60           240            230
# 1              50              30            90             50
# 2              40              30            40             30
# 3              70              50           110             90
# 4              40              50            70             40
# 5             150             160           150            170
# 6             150             140            80             70
# 7               0              30            20             10
# 8             200             210            80             70
# 9             140             150           140            150
# 10             20              10           200            210
# 11             70              80            50             60
# 12            190             190            20              0
# 13             20              10           130            120
# 14             40              50           230            250
# 15             40              50            40             50
# 16             40              60            20             50
# 17             50              40            60             40
# 18             40              30            80             70
# 19             30              30           100             90
# 20             50              40             0              0
# 21            110              90            40             50
# 22             30              40            80             60
# 23             30              40            20             40
# 24             30              20            50             20
# 25             60              50            80             70
# 26             50              40            50             30
# 27             70              50            30             30
# 28             50             100            10             10
# 29            160             150           180            150
# ..            ...             ...           ...            ...
# 52            190             180           260            250
# 53             20              10            70             50
# 54             40              60            20             20
# 55             40              30            20             10
# 56             20               0            70             50
# ...
# 0                            [metallica, music video]  ...             60
# 1   [twenty one pilots, 21 pilots, twentyonepilots...  ...             60
# 2        [OneRepublic, Kids, Mosley, Interscope, Pop]  ...             50
# 3   [Avenged, Sevenfold, The, Stage, Capitol, Reco...  ...             50
# 4   [Panic At The Disco, Panic! At The Disco, PATD...  ...             30
# 5   [twenty one pilots, blurryface, stressed out, ...  ...            150
# 6                                                      ...             70
# 7   [green day, green, day, official, music, music...  ...             50
# 8   [Alternative, Waste A Moment, RCA Records Labe...  ...            120
# 9   [red hot chili peppers, red, hot, chili, peppe...  ...             40
# 10  [WALLS, Alternative, RCA Records Label, Kings ...  ...             60
# 11  [twenty one pilots, blurryface, ride, blurry f...  ...             50
# 12  [ONE OK ROCK, 1 OK ROCK, ONE OKAY ROCK, 1 OKAY...  ...            240
# 13  [green day, green, day, official, music, music...  ...             70
# 14  [blink-182, she's out of her mind, spotify, Wh...  ...             20
# 15  [Ambassadors, Unsteady, KIDinaKORNER/Interscop...  ...             50
# 16  [You Want It Darker, Slow, So Long Marianne, L...  ...            240
# 17  [Disturbed, The Sound Of Silence (Composition)...  ...             30
# 18  [The, Lumineers, Angela, Decca, Records, Alter...  ...             40
# 19  [Oh No, Rock, RCA Records Label, Bring Me The ...  ...             70
# 20  [Moby, Video, Official, Play, 18, Innocents, P...  ...             30
# 21  [Bullet, For, My, Valentine, Don't, Need, You,...  ...            130
# 22  [Korn, New Korn Video, New Korn Song, New Korn...  ...             50
# 23  [ghost, square hammer, popestar, new ep, new s...  ...             60
# 24  [green day, green, day, official, music, music...  ...             20
# 25                                                     ...            150
# 26  [The, Pretty, Reckless, Take, Me, Down, Razor,...  ...            140
# 27  [Robbie, Williams, Party, Russian, Oligarch, H...  ...             10
# 28  [Panic!, Panic! At The Disco, Panic At The DIs...  ...             10
# 29  [music, official, music video, Suicide Squad, ...  ...            160
# ..                                                ...  ...            ...
# 41           [action bronson, atlantic records, vice]  ...             10
# 42                                                     ...             60
# 43  [Fitz and the Tantrums, HandClap, Official Vid...  ...            100
# 44     [The, Lumineers, Ophelia, Decca, Records, Pop]  ...             30
# 45                                                     ...             50
# 46  [Coldplay, Hymn For The Weekend, Official Vide...  ...             10
# 47  [The, 1975, Somebody, Else, Polydor, Alternative]  ...             40
# 48      [AURORA, Went, Too, Far, Decca, Records, Pop]  ...             50
# 49                               [skillet, unleashed]  ...            150
# 50  [The, Lumineers, Cleopatra, Decca, Records, Al...  ...             70
# 51                                                     ...             10
# 52  [RCA Records Label, Fall Out Boy feat. Missy E...  ...             40
# 53  [blink-182, Bored, To, Death, (Official, Video...  ...             20
# 54  [Bastille, good grief, wild, world, Pompeii, f...  ...            260
# 55  [Hopeless Records, sum 41, fat lip, 13 voices,...  ...             70
# 56  [blink-182, No Future, No Future Blink 182, Ma...  ...             80
# 57  [rise records, of mice & men, pain, official m...  ...             20
# 58  [James, Bay, Let, It, Go, Universal, Records, ...  ...             40
# 59  [Imagine, Dragons, Radioactive, Interscope, Al...  ...             10
# 60  [Fall Out Boy, Centuries, Alternative, Fall, O...  ...            260
# 61  [Red Bull Records, redbullrecords, awolnation,...  ...             50
# 62  [Jimmy, Eat, World, The, Middle, DGC/Interscop...  ...            260
# 63  [Jane's, Addiction, Jane, Says, 1988, Nothing,...  ...             80
# 64     [Queens, Of, The, Stone, Age, Interscope, Pop]  ...            100
# 65  [blur, song, official, hd, promo, video, alter...  ...             50
# 66  [lonely day, toxicity, System of a Down live, ...  ...             30
# 67              [Rise, Against, DGC/Interscope, Rock]  ...             20
# 68  [foo fighters, foo fighters official, one by o...  ...             50
# 69  [Breaking, Benjamin, The, Diary, of, Jane, Hol...  ...             30
# 70  [The White Stripes (band), Seven Nation Army, ...  ...             40
#
#     colors_8_blue  colors_8_green  colors_9_red  colors_9_blue  \
# 0              50              40            50             30
# 1              50              40            40              0
# 2              60              70            20             40
# 3              30              30            40             20
# 4               0              10            60            100
# 5             200             200           240            220
# 6              60              50            60             50
# 7              30              40            50             60
# 8             120             100            90            100
# 9              30              20            30             20
# 10             40              30            40             20
# 11             30              30           140            120
# 12            230             220            80            100
# 13             50              40            50             30
# 14             60              30            10              0
# 15             40              30            70             50
# 16             10              30           240             30
# 17             30              50            40             30
# 18             10              10            40             10
# 19             60              50            80             70
# 20             40              60            30             30
# 21            160             170           130            150
# 22             40              30            80             80
# 23             40              20            50             30
# 24              0              40           140            200
# 25            150             170           100            100
# 26            160             170           130            150
# 27             40              40            50             80
# 28             20              40            40             20
# 29            190             210           170            200
# ..            ...             ...           ...            ...
# 41             30              30            30             40
# 42             60              30            40             30
# 43             90               0           140            130
# 44             20              10            40             40
# 45             50              30            60             60
# 46             20               0            30             30
# 47             40              20            50             40
# 48             10               0            10             40
# 49            140             130            80             70
# 50              0               0           200              0
# 51             20               0            10             30
# 52             30              10            40             20
# 53             20               0            50             50
# 54            260             230           260            260
# 55             90              70            40             60
# 56             80              60           150            140
# 57             10               0            10             20
# 58             30              20            80             60
# 59              0              40            30             20
# 60            250             230           260            250
# 61             40              30            30             40
# 62            250             230           260            250
# 63             80             100            90             90
# 64             70              50            90             60
# 65             30              20            30             10
# 66             20              10            90             70
# 67             10               0           100             50
# 68             20              30            60             30
# 69             20              10            40             30
# 70             20               0            30             70
#
#     colors_9_green  colors_10_red  colors_10_blue  colors_10_green  genre
# 0               20             70              50               40   rock
# 1               10             50              30               30   rock
# 2               50             20              30               40   rock
# 3               20             70              50               40   rock
# 4              130             20               0               10   rock
# 5              100             80             210              160   rock
# 6               40            250             240              230   rock
# 7               70             30              40               50   rock
# 8               80            230             220              210   rock
# 9               10             50              40               30   rock
# 10              20             70              60               50   rock
# 11              80            150             120               60   rock
# 12             100            250             240              230   rock
# 13              30             80              70               50   rock
# 14              20             10              10               30   rock
# 15              40             70              40               30   rock
# 16              50             40               0                0   rock
# 17              20             60              60               80   rock
# 18              20             80              10               20   rock
# 19              60            100              90               80   rock
# 20              50             40              50               60   rock
# 21             150            120             150              160   rock
# 22              60             90              90               70   rock
# 23              10             50              30               20   rock
# 24             140            160             210              130   rock
# 25             120             30              40               50   rock
# 26             160            120             130              140   rock
# 27              80             10              50               60   rock
# 28              20             10              10               30   rock
# 29             220            110             140              150   rock
# ..             ...            ...             ...              ...    ...
# 41              50             10              30               20   rock
# 42              10             50              50               20   rock
# 43               0             70              60                0   rock
# 44              20             40              30               20   rock
# 45              30             50              50               20   rock
# 46              10              0              20                0   rock
# 47              20              0              10               20   rock
# 48              40              0              20               30   rock
# 49              60             50              40               30   rock
# 50               0            180               0                0   rock
# 51              30             20              40               40   rock
# 52               0             10              20                0   rock
# 53              30             30              30               10   rock
# 54             240             30              20               10   rock
# 55              50             30              40               20   rock
# 56             130             10              20               30   rock
# 57               0             40              30               10   rock
# 58              40             90              70               50   rock
# 59              60             10               0               60   rock
# 60             240              0              20               30   rock
# 61              70             80             100              140   rock
# 62             220            260             250              240   rock
# 63             110              0               0               20   rock
# 64              40             50              40               30   rock
# 65               0             40              20               20   rock
# 66              70             30              10               10   rock
# 67              20             60              30               10   rock
# 68              40             40              10               20   rock
# 69               0             40              30               10   rock
# 70              10             60              10                0   rock
#
# [71 rows x 42 columns]
# 814
#                                  filename             author  \
# 0         Luke Bryan - Roller Coaster.mp4      LukeBryanVEVO
# 1   Dierks Bentley - Drunk On A Plane.mp4  DierksBentleyVEVO
# 2  Thomas Rhett - Get Me Some Of That.mp4    ThomasRhettVEVO
# 3     David Nail - Whatever She's Got.mp4      DavidNailVEVO
# 4                  Joe Nichols - Yeah.mp4     JoeNicholsVEVO
#
#                                          description  viewcount    rating  \
# 0  Luke Bryan - Crash My Party\nPurchase now on i...   28948653  4.840108
# 1  Purchase Dierks Bentley’s latest music: http:/...   41548786  4.763639
# 2  Music video by Thomas Rhett performing Get Me ...   43868160  4.826069
# 3  Purchase David Nail’s latest music: http://umg...   48648247  4.826632
# 4  Joe Nichols - Yeah\n“Yeah” from Joe Nichol’s C...   11397694  4.815725
#
#     likes  dislikes  duration  length  \
# 0  127866      5324  00:04:23     263
# 1  140682      8835  00:04:51     291
# 2  128488      5841  00:03:13     193
# 3  141108      6393  00:04:01     241
# 4   33255      1606  00:03:52     232
#
#                                             keywords   ...    colors_8_red  \
# 0  [Luke, Bryan, Roller, Coaster, Capitol, Record...   ...             230
# 1  [Dierks, Bentley, Drunk, On, Plane, Capitol, R...   ...              70
# 2  [Thomas, Rhett, Get, Me, Some, Of, That, The, ...   ...              40
# 3  [David, Nail, Whatever, She's, Got, MCA, Nashv...   ...              60
# 4      [Joe Nichols, Red Bow Records, Country, Yeah]   ...              30
#
#    colors_8_blue  colors_8_green  colors_9_red  colors_9_blue  colors_9_green  \
# 0            210             190            90             70              70
# 1             50              50           100            110             120
# 2             50              30            50             70              50
# 3             50              30            60             40              30
# 4             50              50            20             40              60
#
#    colors_10_red  colors_10_blue  colors_10_green    genre
# 0            240             220              200  country
# 1             90              70               70  country
# 2             40              60               50  country
# 3             70              60               50  country
# 4             20              30               50  country
#
# [5 rows x 42 columns]

# %% [markdown]
# ### Ordinal Genres
# Below, we make the genres ordinal to fit in the random forest classifiers. We add a new column to our dataframe to do so, write a function to populate it, and run it across the dataframe.

# %%
def genre_to_ordinal(genre_in):
    if(genre_in == "country"):
        return 0
    elif(genre_in == "pop"):
        return 1
    elif(genre_in == "rock"):
        return 2
    elif(genre_in == "edm"):
        return 3
    elif(genre_in == "rap"):
        return 4
    else:
        return genre_in
    
all_genres['genre_ordinal'] = all_genres.genre.apply(genre_to_ordinal)

# %% [markdown]
# We add in some boolean genre classifiers to make our analysis more fine-grained. Rather than saying "we predict this video is country with 50% confidence", we could say "this video is not edm with 90% confidence" and so on.

# %%
# Adding is_country flag
def is_country(genre_in):
    if(genre_in == "country"):
        return 1
    else:
        return 0
    
all_genres['is_country'] = all_genres.genre.apply(is_country)

# Adding is_country flag
def is_rock(genre_in):
    if(genre_in == "rock"):
        return 1
    else:
        return 0
    
all_genres['is_rock'] = all_genres.genre.apply(is_rock)

# Adding is_edm flag
def is_edm(genre_in):
    if(genre_in == "edm"):
        return 1
    else:
        return 0
    
all_genres['is_edm'] = all_genres.genre.apply(is_edm)

# Adding is_rap flag
def is_rap(genre_in):
    if(genre_in == "rap"):
        return 1
    else:
        return 0
    
all_genres['is_rap'] = all_genres.genre.apply(is_rap)

# Adding is_country flag
def is_pop(genre_in):
    if(genre_in == "pop"):
        return 1
    else:
        return 0
    
all_genres['is_pop'] = all_genres.genre.apply(is_pop)

# %% [markdown]
# ### Test and Train Sets
# We create our training and test sets by splitting all_genres by genre, and making 10 of each genre train and 10 test. We aggregate by genre to make our full train and full test sets, each containing 50 records of various genres.

# %%
import pandas as pd

# Subset all_genres to group by individual genres
country_records  = all_genres[all_genres["genre"] == "country"]
rock_records     = all_genres[all_genres["genre"] == "rock"]
pop_records      = all_genres[all_genres["genre"] == "pop"]
edm_records      = all_genres[all_genres["genre"] == "edm"]
rap_records      = all_genres[all_genres["genre"] == "rap"]

#country_records[['filename','genre']]
# From the subsets above, create train and test sets from each
country_train = country_records.head(len(country_records) / 2)
country_test  = country_records.tail(len(country_records) / 2)
rock_train    = rock_records.head(len(rock_records) / 2)
rock_test     = rock_records.tail(len(rock_records) / 2)
pop_train     = pop_records.head(len(pop_records) / 2)
pop_test      = pop_records.tail(len(pop_records) / 2)
edm_train     = edm_records.head(len(edm_records) / 2)
edm_test      = edm_records.tail(len(edm_records) / 2)
rap_train     = rap_records.head(len(rap_records) / 2)
rap_test      = rap_records.tail(len(rap_records) / 2)


# Create big training and big test set for analysis
training_set = pd.concat([country_train,rock_train,pop_train,edm_train,rap_train])
test_set     = pd.concat([country_test,rock_test,pop_test,edm_test,rap_test])

training_set = training_set.fillna(0)
test_set = test_set.fillna(0)

print "Training:\t" , len(training_set)
print "Test:\t\t" , len(test_set)
# training_set.head()
# Out:
# Training:	405
# Test:		405

# %% [markdown]
# ### Generating Random Forests
# We start generating our random forests, and output a relative accuracy and a confusion matrix. In this first one, we simply factor in non-color variables (rating, likes, dislikes, length and viewcount), and run it across all records to predict an ordinal genre value.

# %%
# Random Forest Classifier
from sklearn.ensemble import RandomForestClassifier
import numpy as np

# Predicting based solely on non-color features
clf = RandomForestClassifier(n_estimators=11)
meta_data_features = ['rating', 'likes','dislikes','length','viewcount']
y, _ = pd.factorize(training_set['genre_ordinal'])
clf = clf.fit(training_set[meta_data_features], y)

z, _ = pd.factorize(test_set['genre_ordinal'])
print clf.score(test_set[meta_data_features],z)
pd.crosstab(test_set.genre_ordinal, clf.predict(test_set[meta_data_features]),rownames=["Actual"], colnames=["Predicted"])
# Out:
# 0.43950617284
# Predicted   0   1   2   3   4
# Actual
# 0          47   7   1  21   5
# 1           1  24  38   9   9
# 2          29  16   2  23   5
# 3           4  22  21  25  11
# 4           6  14   3  10  52

# %% [markdown]
# As shown above, this method yields relatively poor results. This is because there's no distinct clusters being created by our random forest, and simple viewer statistics tell us nothing about what kind of video we're watching. However, we see that country, rap and pop are initially somewhat distinct (diagonal is the highest value), and rock and edm are getting mistaken for one another. Let's see if we can't make something of this.

# %% [markdown]
# ### Random Forest Only Color
# Below, we do the same random forest as above, but going strictly off of average frame color for the video.
#
# We found the most commonly appearing color in each frame and called it the 'frame mode'. We then took all of the frame modes and found the 10 most common of them. Those became the 'color data' we use to analyze videos.

# %%
def gen_new_headers(old_headers):
    headers = ['colors_' + str(x+1) + '_' for x in range(10)]
    h = []
    for x in headers:
        h.append(x + 'red')
        h.append(x + 'blue')
        h.append(x + 'green')
    return old_headers + h + ['genre']

# %%
clf = RandomForestClassifier(n_estimators=11)
color_features = gen_new_headers([])[:-1]

# Predicting based solely on colors
y, _ = pd.factorize(training_set['genre_ordinal'])
clf = clf.fit(training_set[color_features], y)

z, _ = pd.factorize(test_set['genre_ordinal'])
print clf.score(test_set[color_features],z)
pd.crosstab(test_set.genre_ordinal, clf.predict(test_set[color_features]),rownames=["Actual"], colnames=["Predicted"])
# Out:
# 0.222222222222
# Predicted   0   1   2   3   4
# Actual
# 0          22  23  10  15  11
# 1          18  10  16  21  16
# 2          27  21   9  10   8
# 3          20   8  23  18  14
# 4          19  14  22  17  13

# %% [markdown]
# This actually yields worse results than just the viewer statistics, because the color of a video by itself does not determine the genre. If rappers only had red in their videos and rockers only had black this might be somewhat accurate, but that's just not the case. But, what if we pair these findings with our initial viewer statistics?

# %%
clf = RandomForestClassifier(n_estimators=11)
all_features = meta_data_features + color_features

# Predicting based on colors and non-color features
y, _ = pd.factorize(training_set['genre_ordinal'])
clf = clf.fit(training_set[all_features], y)

z, _ = pd.factorize(test_set['genre_ordinal'])
print clf.score(test_set[all_features],z)
pd.crosstab(test_set.genre_ordinal, clf.predict(test_set[all_features]),rownames=["Actual"], colnames=["Predicted"])
# Out:
# 0.353086419753
# Predicted   0   1   2   3   4
# Actual
# 0          33   8   0  30  10
# 1          10  19  34  12   6
# 2          30  20   3  20   2
# 3          11   8  25  24  15
# 4          25  13   2  13  32

# %% [markdown]
# ### Singling Out Pop and Rap
# Scores are expectedly low. It seems as if we're trying to make the classifier do way too much work, and are giving it very mediocre data to go off of. Recall that we're actually trying to determine WHICH genre a video is by the above code, not whether or not a video is of ONE specific genre. This brings back the binary classifiers that we created above, let's put those to use to see if we can improve these scores.

# %% [markdown]
# We try pop and rap first, since they seem to be the most distinct by what we've gathered above.

# %%
clf = RandomForestClassifier(n_estimators=11)
all_features = meta_data_features + color_features

# Predicting based on colors and non-color features
y, _ = pd.factorize(training_set['is_pop'])
clf = clf.fit(training_set[all_features], y)

z, _ = pd.factorize(test_set['is_pop'])
print clf.score(test_set[all_features],z)
pd.crosstab(test_set.is_pop, clf.predict(test_set[all_features]),rownames=["Actual"], colnames=["Predicted"])
# Out:
# 0.804938271605
# Predicted    0   1
# Actual
# 0          301  23
# 1           56  25

# %%
clf = RandomForestClassifier(n_estimators=11)
all_features = meta_data_features + color_features

# Predicting based on colors and non-color features
y, _ = pd.factorize(training_set['is_rap'])
clf = clf.fit(training_set[all_features], y)

z, _ = pd.factorize(test_set['is_rap'])
print clf.score(test_set[all_features],z)
pd.crosstab(test_set.is_rap, clf.predict(test_set[all_features]),rownames=["Actual"], colnames=["Predicted"])
# Out:
# 0.777777777778
# Predicted    0   1
# Actual
# 0          297  23
# 1           67  18

# %% [markdown]
# What we're seeing above is a confusion matrix that, based on our training data, predicts whether or not a video in the test set is a pop video or not. In the "predicted" row, 0 means it predicts it's not a pop video, and that the 1 is. Likewise with the actual, 0 shows that the video actually wasn't a pop video, and the 1 shows that it was.
#
# The confusion matrix above is our first effort at utilizing these binary classifiers. Most of our videos aren't pop videos (40 aren't, 10 are), and the model did a good job of picking out those that aren't pop. However, we could use some improvement in the realm of "false negatives", where the model classified a video as not pop when it actually was.

# %% [markdown]
# We recreated the tests above with each genre, and the results are below:
#
# ##### Ranking performance of boolean classifiers, train and test sets of 50, respectively.
# - 1 - is_pop (.84 avg)
# - 2 - is_rap (.82 avg, fewer true negatives)
# - 3 - is_rock (.78 avg, too many true negatives)
# - 4 - is_edm (.--, DO NOT USE. Rarely predicts a positive edm value)
# - 5 - is_country (.--, DO NOT USE. Way too many false positives)

# %% [markdown]
# We do these tests 50 times for sake of average score.

# %%
clf = RandomForestClassifier(n_estimators=11)

# Average score over many iterations calculation
loop_indices = range(0,50)
cumsum = 0

for i in loop_indices:
    y, _ = pd.factorize(training_set['is_pop'])
    clf = clf.fit(training_set[all_features], y)

    z, _ = pd.factorize(test_set['is_pop'])
    #print clf.score(test_set[all_features],z)
    cumsum = cumsum + clf.score(test_set[all_features],z)
    #print pd.crosstab(test_set.is_pop, clf.predict(test_set[all_features]),rownames=["Actual"], colnames=["Predicted"])
    
print "Average Score for",len(loop_indices),"is_pop iterations:", cumsum/len(loop_indices)
# Out:
# Average Score for 50 is_pop iterations: 0.809432098765

# %%
# Average score over many iterations calculation
loop_indices = range(0,50)
cumsum = 0

for i in loop_indices:
    y, _ = pd.factorize(training_set['is_rap'])
    clf = clf.fit(training_set[all_features], y)

    z, _ = pd.factorize(test_set['is_rap'])
    #print clf.score(test_set[all_features],z)
    cumsum = cumsum + clf.score(test_set[all_features],z)
    #print pd.crosstab(test_set.is_pop, clf.predict(test_set[all_features]),rownames=["Actual"], colnames=["Predicted"])
    
print "Average Score for",len(loop_indices),"is_rap iterations:", cumsum/len(loop_indices)
# Out:
# Average Score for 50 is_rap iterations: 0.783950617284

# %% [markdown]
# Rather than hard-coding each time we wanted to run something for average, we wrote a function that does it for us. All we have to do is pass in the boolean classifier in quotes ("is_rock", etc.), and the number of iterations that we want. Results are displayed below.

# %%
def multi_RF_averages(is_genre,num_iterations):
    clf = RandomForestClassifier(n_estimators=11)
    loop_indices = range(0,num_iterations)
    cumsum = 0

    for i in loop_indices:
        y, _ = pd.factorize(training_set[is_genre])
        clf = clf.fit(training_set[all_features], y)

        z, _ = pd.factorize(test_set[is_genre])
        cumsum = cumsum + clf.score(test_set[all_features],z)
    
    print "Average Score for",len(loop_indices),is_genre,"iterations:", cumsum/len(loop_indices)

# %%
multi_RF_averages("is_pop",50)
multi_RF_averages("is_rap",50)
multi_RF_averages("is_rock",50)
multi_RF_averages("is_edm",50)
multi_RF_averages("is_country",50)
# Out:
# Average Score for 50 is_pop iterations: 0.810419753086
# Average Score for 50 is_rap iterations: 0.779111111111
# Average Score for 50 is_rock iterations: 0.81412345679

# %% [markdown]
# We ran the above test with all genres, and as shown in above analysis, our country and edm typically have very low accuracy. We've seen above that edm and rock videos are getting mixed up with one another, so we assume that something is characteristic of these 2 genres that's not of everything else. We take out the edm values from our training and test datasets, hoping to improve accuracy.

# %%
# Removing EDM for better analysis - makes is_pop and is_rap much more accurate
training_set = pd.concat([country_train,rock_train,pop_train,rap_train])
test_set     = pd.concat([country_test,rock_test,pop_test,rap_test])

multi_RF_averages("is_pop",50)
multi_RF_averages("is_rap",50)
multi_RF_averages("is_rock",50)
multi_RF_averages("is_edm",50)
multi_RF_averages("is_country",50)

# %% [markdown]
# So, what does this tell us? Based on our training data, we have the best chance of accurately classifying something as pop or not pop (under these conditions).

# %% [markdown]
# We want to find out which 2 are the most distinct, so we can make build our model based on that classification.

# %%
training_set = pd.concat([country_train,rock_train,edm_train,rap_train,pop_train])

test_set     = pd.concat([rock_test])
multi_RF_averages("is_rock",50)

test_set     = pd.concat([rap_test])
multi_RF_averages("is_rap",50)

test_set     = pd.concat([country_test])
multi_RF_averages("is_country",50)

test_set     = pd.concat([pop_test])
multi_RF_averages("is_pop",50)

test_set     = pd.concat([edm_test])
multi_RF_averages("is_edm",50)

# %% [markdown]
# Rock and EDM have suprisingly distinct classifiers. We should dive into the videos and see what this means.

# %%
test_set     = pd.concat([edm_test,rock_test])
multi_RF_averages("is_edm",50)
multi_RF_averages("is_rock",50)

# %%
from sklearn.ensemble import ExtraTreesClassifier
import sklearn
model = ExtraTreesClassifier()

training_set = pd.concat([country_train,pop_train,rap_train,rock_train,edm_train])
y, _ = pd.factorize(training_set['is_rock'])
model.fit(training_set[all_features], y)

# display the relative importance of each attribute
print model.feature_importances_
# Out:
# [ 0.03337338  0.03162425  0.03959774  0.0611266   0.02978028  0.02920987
#   0.02369245  0.0217159   0.02970311  0.0206494   0.03021141  0.02703575
#   0.02305317  0.02361534  0.03102654  0.02066348  0.0251116   0.0243787
#   0.02277858  0.03526039  0.02929496  0.03550097  0.02914601  0.02482491
#   0.02585437  0.02081204  0.03555002  0.01866605  0.0292887   0.02989434
#   0.03719211  0.01332665  0.02772888  0.02989153  0.02942052]

# %%
df = pd.DataFrame(all_features,model.feature_importances_)
